# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
movies = pd.read_csv('/content/tmdb_5000_movies.csv')
credits = pd.read_csv('/content/tmdb_5000_credits.csv')

# %%
movies.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
movies.shape
# Out:
# (4803, 20)

# %%
movies = movies[['id', 'title', 'overview', 'genres','keywords']]

# %%
movies.head()
# Out:
#        id                                     title  \
# 0   19995                                    Avatar
# 1     285  Pirates of the Caribbean: At World's End
# 2  206647                                   Spectre
# 3   49026                     The Dark Knight Rises
# 4   49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                               genres  \
# 0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
# ...

# %%
movies.isnull().sum()
# Out:
# id          0
# title       0
# overview    3
# genres      0
# keywords    0
# dtype: int64

# %%
movies.dropna(inplace=True)

# %%
import ast

def convert(text):
    L = []

    for i in ast.literal_eval(text):
        L.append(i['name'])

    return L

# %%
movies['genres'] = movies['genres'].apply(convert)

# %%
movies['keywords'] = movies['keywords'].apply(convert)

# %%
movies['overview'] = movies['overview'].apply(
    lambda x: x.split() if isinstance(x, str) else []
)

# %%
movies['tags'] = movies['overview'] + movies['genres'] + movies['keywords']

# %%
movies['tags'] = movies['tag'].apply(lambda x: ' '.join(x))

# %%
movies[['title','tags']].head()
# Out:
#                                       title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                                 tags
# 0  A c t i o n   A d v e n t u r e   F a n t a s ...
# 1  A d v e n t u r e   F a n t a s y   A c t i o ...
# 2  A c t i o n   A d v e n t u r e   C r i m e   ...
# 3  A c t i o n   C r i m e   D r a m a   T h r i ...
# 4  A c t i o n   A d v e n t u r e   S c i e n c ...

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
cv = CountVectorizer(max_features=5000, stop_words='english')

# %%
vectors = cv.fit_transform(movies['tag']).toarray()

# %%
vectors.shape
# Out:
# (4800, 5000)

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity = cosine_similarity(vectors)

# %%
def recommend(movie):
  index = movies[movies['title'].str.lower()==movie.lower()].index[0]
  distance = similarity[index]
  movie_list = sorted(
      list(enumerate(distance)),
      reverse=True,
      key=lambda x:x[1]
  )[1:6]

  for i in movie_list:
    print(movies.iloc[i[0]].title)

# %%
recommend('Avatar')
# Out:
# Planet of the Apes
# Soldier
# Mission to Mars
# Alien³
# Aliens

# %% [markdown]
# # 🎬 Movie Recommendation System
#
# ## 📌 Project Overview
#
# This project is a content-based movie recommendation system.
# It recommends movies that are similar to a movie selected by the user.
#
# ## 🎯 Objective
#
# The main objective of this project is to recommend similar movies
# using movie information such as genres, keywords and overview.
#
# ## 🛠️ Technologies Used
#
# - Python
# - Pandas
# - NumPy
# - Scikit-learn
# - Google Colab
#
# ## 🤖 Machine Learning Technique
#
# Content-Based Recommendation
#
# ## 📊 Dataset
#
# TMDB 5000 Movie Dataset
#
# ## ⚙️ Methodology
#
# 1. Load the movie dataset
# 2. Clean the data
# 3. Extract useful movie information
# 4. Combine movie features
# 5. Convert text features into numerical vectors
# 6. Calculate movie similarity
# 7. Recommend the top 5 similar movies
#
# ## ✅ Result
#
# The system successfully recommends five movies
# similar to the movie entered by the user.

# %%
movie_name = input("enter a movie name: ")
recommend(movie_name)
# Out:
# enter a movie name: avatar
# Planet of the Apes
# Soldier
# Mission to Mars
# Alien³
# Aliens

# %%
movie_name = input("enter a movie name: ")
recommend(movie_name)
# Out:
# enter a movie name: john carter
# Mission to Mars
# Ender's Game
# The 5th Wave
# Stargate: The Ark of Truth
# Planet 51
